# %% [markdown]
# # Task 1: Analysis of Symptom Co-Occurrence Patterns using Apriori Algorithm with non-merged data

# %% [markdown]
# ## 1.1 Setup and Imports

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
from apriori_miner import AprioriMiner

# %% [markdown]
# ## Data Extraction and processing for Apriori ALgorithm

# %%
def convert_to_transactions(df, keep_disease_label=False):
    """
    Convert disease-symptom dataframe to transaction format for Apriori.

    Each ROW becomes a transaction containing its symptoms.

    Parameters:
    - df: DataFrame with Disease and Symptom columns
    - keep_disease_label: If True, return (disease, symptoms) tuples

    Returns:
    - If keep_disease_label=False: list of frozensets
    - If keep_disease_label=True: list of (disease, frozenset) tuples
    """
    transactions = []
    symptom_cols = [col for col in df.columns if "Symptom" in col]

    for _, row in df.iterrows():
        disease = row["Disease"]
        # Collect non-null symptoms for this row
        symptoms = [row[col] for col in symptom_cols if pd.notna(row[col])]

        # Only add if there are symptoms
        if symptoms:
            if keep_disease_label:
                transactions.append((disease, frozenset(symptoms)))
            else:
                transactions.append(frozenset(symptoms))

    return transactions


# ============================================================================
# Convert dataset to transactions
# ============================================================================

# Load raw data
df_raw = pd.read_csv("raw/itachi9604_disease-symptom-description-dataset.csv")
print(f"Raw data shape: {df_raw.shape}")
print(f"Unique diseases: {df_raw['Disease'].nunique()}")
print(f"Total patient instances: {len(df_raw)}")
display(df_raw.head())


# Convert to transactions (each row = one patient instance)
transactions = convert_to_transactions(df_raw, keep_disease_label=False)
transactions_with_labels = convert_to_transactions(
    df_raw, keep_disease_label=True
)

print(f"\nTotal transactions: {len(transactions)}")
print(f"Example transaction: {list(transactions[0])[:5]}...")

# Show disease distribution
disease_counts = df_raw["Disease"].value_counts()
print("\nTop 10 diseases by instance count:")
print(disease_counts.head(10))
# Out:
# Raw data shape: (4920, 18)
# Unique diseases: 41
# Total patient instances: 4920
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# Total transactions: 4920
# Example transaction: [' skin_rash', ' nodal_skin_eruptions', 'itching', ' dischromic _patches']...
#
# Top 10 diseases by instance count:
# Disease
# Fungal infection                120
# Hepatitis C                     120
# Hepatitis E                     120
# Alcoholic hepatitis             120
# Tuberculosis                    120
# Common Cold                     120
# Pneumonia                       120
# Dimorphic hemmorhoids(piles)    120
# Heart attack                    120
# Varicose veins                  120
# Name: count, dtype: int64

# %% [markdown]
# ## Apriori Algorithm
# ### Minsup = 0.9

# %%
# Run Apriori on ALL patient instances
print("\n" + "=" * 80)
print("RUNNING APRIORI ON PATIENT-LEVEL DATA")
print("=" * 80)

miner = AprioriMiner(min_support=0.05)
frequent_itemsets = miner.fit(transactions)
rules = miner.generate_rules(min_confidence=0.6)

print(f"Frequent itemsets: {len(frequent_itemsets)}")
print(f"Association rules: {len(rules)}")
# Out:
# ================================================================================
# RUNNING APRIORI ON PATIENT-LEVEL DATA
# ================================================================================
# Fitting Apriori with min_support=0.05 (count=246)
# Total transactions: 4920
# Generating 1-itemsets...
#   Found 31 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 104 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 153 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 143 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 86 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 36 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 9 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 0 frequent 8-itemsets
# Total frequent itemsets: 562
#
# Generated 5463 association rules
#   Min confidence: 0.6
#   Min lift: 1.0
# Frequent itemsets: 562
# Association rules: 5463

# %%
# Running Apriori on a per-disease analysis
print("\n" + "=" * 80)
print("PER-DISEASE ANALYSIS")
print("=" * 80)

for disease in df_raw["Disease"].unique()[:5]:  # Top 5 for demo
    disease_df = df_raw[df_raw["Disease"] == disease]
    disease_transactions = convert_to_transactions(disease_df)

    if len(disease_transactions) < 3:
        print(f"\n{disease}: Skipped (only {len(disease_transactions)} "
              f"instances)")
        continue

    miner_disease = AprioriMiner(min_support=0.3)  # Higher threshold
    itemsets_disease = miner_disease.fit(disease_transactions)

    print(f"\n{disease} ({len(disease_transactions)} instances):")
    print(f"  Core symptom combinations: {len(itemsets_disease)}")
# Out:
# ================================================================================
# PER-DISEASE ANALYSIS
# ================================================================================
# Fitting Apriori with min_support=0.3 (count=36)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 6 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 4 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1 frequent 4-itemsets
# Total frequent itemsets: 15
#
# Fungal infection (120 instances):
#   Core symptom combinations: 15
# Fitting Apriori with min_support=0.3 (count=36)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 6 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 4 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1 frequent 4-itemsets
# Total frequent itemsets: 15
#
# Allergy (120 instances):
#   Core symptom combinations: 15
# Fitting Apriori with min_support=0.3 (count=36)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 15 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 20 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 15 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 6 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 1 frequent 6-itemsets
# Total frequent itemsets: 63
#
# GERD (120 instances):
#   Core symptom combinations: 63
# Fitting Apriori with min_support=0.3 (count=36)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 7 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 21 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 35 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 35 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 21 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 7 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 1 frequent 7-itemsets
# Total frequent itemsets: 127
#
# Chronic cholestasis (120 instances):
#   Core symptom combinations: 127
# Fitting Apriori with min_support=0.3 (count=36)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 10 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 10 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 5 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 1 frequent 5-itemsets
# Total frequent itemsets: 31
#
# Drug Reaction (120 instances):
#   Core symptom combinations: 31

# %% [markdown]
# ## Data Visualisation

# %%
# ============================================================================
# Visualising overall disease symptom statistics and longest symptom frquent itemsets (minsup=0.9)
# ============================================================================

disease_stats = []
longest_itemsets = []

for disease in df_raw["Disease"].unique():
    disease_df = df_raw[df_raw["Disease"] == disease]
    disease_transactions = convert_to_transactions(disease_df)
    
    # Skip very small diseases
    if len(disease_transactions) < 3:
        continue

    print(f"Processing disease - {disease}")
    
    # Shared stats
    avg_symptoms = float(np.mean([len(t) for t in disease_transactions]))
    unique_symptoms_count = len(set().union(*disease_transactions))

    # -------------------------------------------------
    # Single Apriori run with min_support = 0.9
    # -------------------------------------------------
    miner = AprioriMiner(min_support=0.9)
    miner.fit(disease_transactions)

    # ---- STATS DF PART ----
    disease_stats.append({
        "disease": disease,
        "instances": len(disease_transactions),
        "frequent_itemsets": len(miner.all_frequent_itemsets),
        "avg_symptoms": avg_symptoms,
        "unique_symptoms": unique_symptoms_count
    })

    # ---- RESULTS DF PART (only if we have itemsets) ----
    if not miner.all_frequent_itemsets:
        continue

    max_k = max(len(items) for items, _ in miner.all_frequent_itemsets)

    longest_items, support_count = max(
        ((items, count) for items, count in miner.all_frequent_itemsets
         if len(items) == max_k),
        key=lambda x: x[1]
    )

    support = support_count / len(disease_transactions)
    longest_itemset_str = ", ".join(sorted(longest_items))

    longest_itemsets.append({
        "disease": disease,
        "longest_itemset_string": longest_itemset_str,
        "length_of_longest_itemset": max_k,
        "support": support,
        "support_count": support_count,
        "avg_symptoms": avg_symptoms
    })

# Build dataframes
stats_df = pd.DataFrame(disease_stats)
longest_itemsets_df = pd.DataFrame(longest_itemsets)

# ===================== PLOTS =========================
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Frequent itemsets per disease
top_20 = stats_df.nlargest(20, "frequent_itemsets")
axes[0, 0].barh(range(len(top_20)), top_20["frequent_itemsets"], color="steelblue")
axes[0, 0].set_yticks(range(len(top_20)))
axes[0, 0].set_yticklabels(top_20["disease"], fontsize=9)
axes[0, 0].set_xlabel("Number of Frequent Itemsets (min_support=0.9)")
axes[0, 0].set_title("Top 20 Diseases by Symptom Pattern Complexity", fontweight="bold")
axes[0, 0].invert_yaxis()
axes[0, 0].grid(axis="x", alpha=0.3)

# 2. Average symptoms per disease
top_20_symptoms = stats_df.nlargest(20, "avg_symptoms")
axes[0, 1].barh(range(len(top_20_symptoms)), top_20_symptoms["avg_symptoms"], color="coral")
axes[0, 1].set_yticks(range(len(top_20_symptoms)))
axes[0, 1].set_yticklabels(top_20_symptoms["disease"], fontsize=9)
axes[0, 1].set_xlabel("Average Symptoms per Patient")
axes[0, 1].set_title("Top 20 Diseases by Average Symptom Count", fontweight="bold")
axes[0, 1].invert_yaxis()
axes[0, 1].grid(axis="x", alpha=0.3)

# 3. Unique symptoms per disease
top_20_unique = stats_df.nlargest(20, "unique_symptoms")
axes[1, 0].barh(range(len(top_20_unique)), top_20_unique["unique_symptoms"],color="seagreen")
axes[1, 0].set_yticks(range(len(top_20_unique)))
axes[1, 0].set_yticklabels(top_20_unique["disease"], fontsize=9)
axes[1, 0].set_xlabel("Number of Unique Symptoms")
axes[1, 0].set_title("Top 20 Diseases by Symptom Diversity", fontweight="bold")
axes[1, 0].invert_yaxis()
axes[1, 0].grid(axis="x", alpha=0.3)

# 4. Scatter: Complexity vs Diversity
axes[1, 1].scatter(stats_df["unique_symptoms"], 
                   stats_df["frequent_itemsets"],
                   s=stats_df["avg_symptoms"]*50, 
                   alpha=0.6, c=stats_df["avg_symptoms"],
                   cmap="viridis")
axes[1, 1].set_xlabel("Unique Symptoms")
axes[1, 1].set_ylabel("Frequent Itemsets")
axes[1, 1].set_title("Pattern Complexity vs Symptom Diversity\n"
                     "(size = avg symptoms)", fontweight="bold")
axes[1, 1].grid(alpha=0.3)

# Add colorbar
cbar = plt.colorbar(axes[1, 1].collections[0], ax=axes[1, 1])
cbar.set_label("Avg Symptoms")

plt.tight_layout()
plt.savefig("disease_complexity_analysis.png", dpi=300, bbox_inches="tight")
plt.show()

longest_itemsets_df
# Out:
# Processing disease - Fungal infection
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Allergy
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - GERD
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 3 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 9
# Processing disease - Chronic cholestasis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 7 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 21 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 28
# Processing disease - Drug Reaction
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 5
# Processing disease - Peptic ulcer diseae
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 6 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 12
# Processing disease - AIDS
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Diabetes
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 10 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 45 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 64 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 28 frequent 4-itemsets
# Generating 5-itemsets...
# Total frequent itemsets: 147
# Processing disease - Gastroenteritis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Bronchial Asthma
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 6 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 12
# Processing disease - Hypertension
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 1 frequent 2-itemsets
# Total frequent itemsets: 6
# Processing disease - Migraine
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 9 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 36 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 45
# Processing disease - Cervical spondylosis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 3 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 8
# Processing disease - Paralysis (brain hemorrhage)
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Jaundice
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 8 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 28 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 36
# Processing disease - Malaria
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 8 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 22 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 15 frequent 3-itemsets
# Generating 4-itemsets...
# Total frequent itemsets: 45
# Processing disease - Chicken pox
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 11 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 55 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 81 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 36 frequent 4-itemsets
# Generating 5-itemsets...
# Total frequent itemsets: 183
# Processing disease - Dengue
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 14 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 91 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 280 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 455 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 406 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 189 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 36 frequent 7-itemsets
# Generating 8-itemsets...
# Total frequent itemsets: 1471
# Processing disease - Typhoid
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 11 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 55 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 109 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 92 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 28 frequent 5-itemsets
# Generating 6-itemsets...
# Total frequent itemsets: 295
# Processing disease - hepatitis A
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 11 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 55 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 109 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 92 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 28 frequent 5-itemsets
# Generating 6-itemsets...
# Total frequent itemsets: 295
# Processing disease - Hepatitis B
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 12 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 66 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 164 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 201 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 120 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 28 frequent 6-itemsets
# Generating 7-itemsets...
# Total frequent itemsets: 591
# Processing disease - Hepatitis C
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 10 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 16
# Processing disease - Hepatitis D
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 9 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 36 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 45
# Processing disease - Hepatitis E
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 13 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 78 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 230 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 365 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 321 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 148 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 28 frequent 7-itemsets
# Generating 8-itemsets...
# Total frequent itemsets: 1183
# Processing disease - Alcoholic hepatitis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 7 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 21 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 28
# Processing disease - Tuberculosis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 16 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 120 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 504 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1302 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 2184 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 2436 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 1800 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 849 frequent 8-itemsets
# Generating 9-itemsets...
#   Found 232 frequent 9-itemsets
# Generating 10-itemsets...
#   Found 28 frequent 10-itemsets
# Generating 11-itemsets...
# Total frequent itemsets: 9471
# Processing disease - Common Cold
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 17 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 136 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 624 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1806 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 3486 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 4620 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 4236 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 2649 frequent 8-itemsets
# Generating 9-itemsets...
#   Found 1081 frequent 9-itemsets
# Generating 10-itemsets...
#   Found 260 frequent 10-itemsets
# Generating 11-itemsets...
#   Found 28 frequent 11-itemsets
# Generating 12-itemsets...
# Total frequent itemsets: 18943
# Processing disease - Pneumonia
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 11 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 55 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 109 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 92 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 28 frequent 5-itemsets
# Generating 6-itemsets...
# Total frequent itemsets: 295
# Processing disease - Dimorphic hemmorhoids(piles)
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 10 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 15
# Processing disease - Heart attack
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Varicose veins
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 7 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 15 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 22
# Processing disease - Hypothyroidism
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 13 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 72 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 215 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 380 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 411 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 268 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 97 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 15 frequent 8-itemsets
# Generating 9-itemsets...
# Total frequent itemsets: 1471
# Processing disease - Hyperthyroidism
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 11 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 55 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 109 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 92 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 28 frequent 5-itemsets
# Generating 6-itemsets...
# Total frequent itemsets: 295
# Processing disease - Hypoglycemia
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 12 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 66 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 164 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 201 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 120 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 28 frequent 6-itemsets
# Generating 7-itemsets...
# Total frequent itemsets: 591
# Processing disease - Osteoarthristis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 15 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 21
# Processing disease - Arthritis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 5 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 10 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 15
# Processing disease - (vertigo) Paroymsal  Positional Vertigo
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 10 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 16
# Processing disease - Acne
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 0 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Urinary tract infection
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 3 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 1 frequent 2-itemsets
# Total frequent itemsets: 4
# Processing disease - Psoriasis
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 6 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 15 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 21
# Processing disease - Impetigo
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 4 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 6 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 0 frequent 3-itemsets
# Total frequent itemsets: 10
#                                     disease  \
# 0                          Fungal infection
# 1                                   Allergy
# 2                                      GERD
# 3                       Chronic cholestasis
# 4                             Drug Reaction
# 5                       Peptic ulcer diseae
# 6                                      AIDS
# 7                                 Diabetes
# 8                           Gastroenteritis
# 9                          Bronchial Asthma
# 10                            Hypertension
# 11                                 Migraine
# 12                     Cervical spondylosis
# 13             Paralysis (brain hemorrhage)
# 14                                 Jaundice
# 15                                  Malaria
# 16                              Chicken pox
# 17                                   Dengue
# 18                                  Typhoid
# 19                              hepatitis A
# 20                              Hepatitis B
# 21                              Hepatitis C
# 22                              Hepatitis D
# 23                              Hepatitis E
# 24                      Alcoholic hepatitis
# 25                             Tuberculosis
# 26                              Common Cold
# 27                                Pneumonia
# 28             Dimorphic hemmorhoids(piles)
# 29                             Heart attack
# 30                           Varicose veins
# 31                           Hypothyroidism
# 32                          Hyperthyroidism
# 33                             Hypoglycemia
# 34                          Osteoarthristis
# 35                                Arthritis
# 36  (vertigo) Paroymsal  Positional Vertigo
# 37                                     Acne
# 38                  Urinary tract infection
# 39                                Psoriasis
# 40                                 Impetigo
#
#                                longest_itemset_string  \
# 0                                           skin_rash
# 1                                 continuous_sneezing
# 2                           chest_pain,  stomach_pain
# 3                                   vomiting, itching
# 4                                             itching
# 5                         internal_itching,  vomiting
# 6                                          high_fever
# 7    increased_appetite,  lethargy,  polyuria,  we...
# 8                                           diarrhoea
# 9                         family_history,  high_fever
# 10            lack_of_concentration,  loss_of_balance
# 11                                 acidity,  headache
# 12                        loss_of_balance,  neck_pain
# 13                                  altered_sensorium
# 14                                  vomiting, itching
# 15                    chills,  muscle_pain,  vomiting
# 16   fatigue,  loss_of_appetite,  malaise,  red_sp...
# 17   back_pain,  headache,  high_fever,  loss_of_a...
# 18   chills,  constipation,  diarrhoea,  fatigue, ...
# 19   joint_pain,  mild_fever,  muscle_pain,  yello...
# 20   dark_urine,  fatigue,  malaise,  receiving_bl...
# 21                  loss_of_appetite,  yellowish_skin
# 22                      joint_pain,  loss_of_appetite
# 23   abdominal_pain,  coma,  fatigue,  loss_of_app...
# 24        distention_of_abdomen,  swelling_of_stomach
# 25   blood_in_sputum,  breathlessness,  chest_pain...
# 26   chest_pain,  congestion,  fatigue,  loss_of_s...
# 27   breathlessness,  chest_pain,  fast_heart_rate...
# 28                 bloody_stool,  pain_in_anal_region
# 29                                         chest_pain
# 30                 bruising,  prominent_veins_on_calf
# 31   abnormal_menstruation,  brittle_nails,  depre...
# 32   abnormal_menstruation,  irritability,  muscle...
# 33   excessive_hunger,  fatigue,  irritability,  p...
# 34                       joint_pain,  painful_walking
# 35               movement_stiffness,  painful_walking
# 36                                  nausea,  vomiting
# 37                                          skin_rash
# 38      bladder_discomfort,  continuous_feel_of_urine
# 39          inflammatory_nails,  small_dents_in_nails
# 40                                blister,  skin_rash
#
#     length_of_longest_itemset  support  support_count  avg_symptoms
# 0                           1     0.90            108          3.60
# 1                           1     0.90            108          3.60
# 2                           2     0.90            108          5.55
# 3                           2     0.90            108          6.65
# 4                           1     0.95            114          4.55
# 5                           2     0.90            108          5.60
# 6                           1     0.95            114          3.65
# 7                           4     0.90            108          9.60
# 8                           1     0.95            114          3.65
# 9                           2     0.90            108          5.60
# 10                          2     0.90            108          4.60
# 11                          2     0.90            108          8.55
# 12                          2     0.90            108          4.65
# 13                          1     0.95            114          3.65
# 14                          2     0.90            108          7.60
# 15                          3     0.90            108          7.60
# 16                          4     0.90            108         10.55
# 17                          7     0.90            108         13.55
# 18                          5     0.90            108         10.60
# 19                          5     0.90            108         10.60
# 20                          6     0.90            108         11.60
# 21                          2     0.90            108          5.65
# 22                          2     0.90            108          8.55
# 23                          7     0.90            108         12.60
# 24                          2     0.90            108          6.65
# 25                         10     0.90            108         15.60
# 26                         11     0.90            108         16.60
# 27                          5     0.90            108         10.60
# 28                          2     0.90            108          4.75
# 29                          1     0.95            114          3.65
# 30                          2     0.90            108          6.60
# 31                          8     0.90            108         12.60
# 32                          5     0.90            108         10.60
# 33                          6     0.90            108         11.60
# 34                          2     0.90            108          5.70
# 35                          2     0.90            108          4.75
# 36                          2     0.90            108          5.65
# 37                          1     0.95            114          3.65
# 38                          2     0.90            108          3.65
# 39                          2     0.90            108          5.70
# 40                          2     0.90            108          4.65

# %% [markdown]
# ### Discriminitive Longest Itemsets
# By extracting the longest itemsets for each disease with a minsup = 0.9, clinicians can confidently diagnose a disease with 90% accuracy if a patient displays ALL of these symptoms.

# %%
from collections import defaultdict

itemset_to_diseases = defaultdict(set)

for _, row in longest_itemsets_df.iterrows():
    items = frozenset(row["longest_itemset_string"].split(", "))
    itemset_to_diseases[items].add(row["disease"])

discriminative_rows = []

for items, diseases in itemset_to_diseases.items():
    if len(diseases) == 1:
        disease = list(diseases)[0]
        row = longest_itemsets_df[longest_itemsets_df["disease"] == disease].iloc[0]
        discriminative_rows.append(row)

discriminative_df = pd.DataFrame(discriminative_rows)
print(f"Number of diseases with discriminative itemsets: {len(discriminative_df)}")
# Out:
# Number of diseases with discriminative itemsets: 37

# %%
# Complexity = k if discriminative else 0
longest_itemsets_df["distinctive_complexity"] = np.where(
    longest_itemsets_df["disease"].isin(discriminative_df["disease"]),
    longest_itemsets_df["length_of_longest_itemset"],
    0
)

# Sort by complexity
plot_df = longest_itemsets_df.sort_values("distinctive_complexity", ascending=True)

plt.figure(figsize=(12, 12))
plt.barh(
    plot_df["disease"],
    plot_df["distinctive_complexity"],
    color=["green" if c > 0 else "lightgray" for c in plot_df["distinctive_complexity"]]
)

plt.xlabel("Distinctive Itemset Complexity (Length k)")
plt.ylabel("Disease")
plt.title("Distinctive Symptom Pattern Complexity Across Diseases")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Uniformity Check
# Given that diseases such as Common Cold, Tuberculosis, Hypothyroidism, and Diabetes Mellitus have a high number of patient instances, we can check if their symptom patterns are uniform across instances.

# %%
# Check for data uniformity across diseases
uniformity_scores = []

for disease in df_raw["Disease"].unique():
    disease_df = df_raw[df_raw["Disease"] == disease]
    disease_transactions = convert_to_transactions(disease_df)
    
    if len(disease_transactions) < 10:
        continue
    
    # Check if all transactions are identical
    unique_trans = set(disease_transactions)
    uniformity = 1 - (len(unique_trans) / len(disease_transactions))
    
    uniformity_scores.append({
        "disease": disease,
        "unique_patterns": len(unique_trans),
        "uniformity": uniformity
    })

uniformity_df = pd.DataFrame(uniformity_scores)
# print(uniformity_df.sort_values("uniformity", ascending=False))
uniformity_df
# Out:
#                                     disease  unique_patterns  uniformity
# 0                          Fungal infection                5    0.958333
# 1                                   Allergy                5    0.958333
# 2                                      GERD                7    0.941667
# 3                       Chronic cholestasis                8    0.933333
# 4                             Drug Reaction                6    0.950000
# 5                       Peptic ulcer diseae                7    0.941667
# 6                                      AIDS                5    0.958333
# 7                                 Diabetes                 9    0.925000
# 8                           Gastroenteritis                5    0.958333
# 9                          Bronchial Asthma                7    0.941667
# 10                            Hypertension                 6    0.950000
# 11                                 Migraine               10    0.916667
# 12                     Cervical spondylosis                6    0.950000
# 13             Paralysis (brain hemorrhage)                5    0.958333
# 14                                 Jaundice                9    0.925000
# 15                                  Malaria                8    0.933333
# 16                              Chicken pox               10    0.916667
# 17                                   Dengue               10    0.916667
# 18                                  Typhoid                9    0.925000
# 19                              hepatitis A                9    0.925000
# 20                              Hepatitis B                9    0.925000
# 21                              Hepatitis C                7    0.941667
# 22                              Hepatitis D               10    0.916667
# 23                              Hepatitis E                9    0.925000
# 24                      Alcoholic hepatitis                8    0.933333
# 25                             Tuberculosis                9    0.925000
# 26                              Common Cold                9    0.925000
# 27                                Pneumonia                9    0.925000
# 28             Dimorphic hemmorhoids(piles)                6    0.950000
# 29                             Heart attack                5    0.958333
# 30                           Varicose veins                8    0.933333
# 31                           Hypothyroidism                8    0.933333
# 32                          Hyperthyroidism                9    0.925000
# 33                             Hypoglycemia                9    0.925000
# 34                          Osteoarthristis                7    0.941667
# 35                                Arthritis                6    0.950000
# 36  (vertigo) Paroymsal  Positional Vertigo                7    0.941667
# 37                                     Acne                5    0.958333
# 38                  Urinary tract infection                5    0.958333
# 39                                Psoriasis                7    0.941667
# 40                                 Impetigo                6    0.950000

# %% [markdown]
# Data is highly uniform. This means even at high minSup values, the number of frequent itemsets likely remains very high, especially for diseases with large number of symptoms, like common cold (no. of symptoms = 17).

# %%
# Select top 6 most interesting diseases
from collections import Counter


# Get extremes for each metric while ensuring uniqueness
interesting_diseases = []
seen = set()

metrics = ["unique_symptoms", "avg_symptoms", "frequent_itemsets"]

for metric in metrics:
    # Get largest
    for _, row in stats_df.nlargest(10, metric).iterrows():
        disease = row["disease"]
        if disease not in seen:
            interesting_diseases.append(disease)
            seen.add(disease)
            if len(interesting_diseases) >= 6:
                break
    
    if len(interesting_diseases) >= 6:
        break
    
    # Get smallest
    for _, row in stats_df.nsmallest(10, metric).iterrows():
        disease = row["disease"]
        if disease not in seen:
            interesting_diseases.append(disease)
            seen.add(disease)
            if len(interesting_diseases) >= 6:
                break
    
    if len(interesting_diseases) >= 6:
        break

# Trim to 6
interesting_diseases = interesting_diseases[:6]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for idx, disease in enumerate(interesting_diseases):
    disease_df = df_raw[df_raw["Disease"] == disease]
    disease_transactions = convert_to_transactions(disease_df)
    
    # Get symptom frequencies
    symptom_counts = Counter()
    for t in disease_transactions:
        symptom_counts.update(t)
    
    # Sort by frequency
    symptoms = [s for s, _ in symptom_counts.most_common(15)]
    frequencies = [symptom_counts[s]/len(disease_transactions) for s in symptoms]
    
    # Plot
    axes[idx].barh(range(len(symptoms)), frequencies, 
                   color=plt.cm.viridis(np.array(frequencies)))
    axes[idx].set_yticks(range(len(symptoms)))
    axes[idx].set_yticklabels(symptoms, fontsize=8)
    axes[idx].set_xlabel("Frequency (%)", fontsize=9)
    axes[idx].set_xlim(0, 1.05)
    
    # Add percentage labels
    for i, (symptom, freq) in enumerate(zip(symptoms, frequencies)):
        axes[idx].text(freq + 0.02, i, f"{freq*100:.0f}%", 
                      va="center", fontsize=7)
    
    # Title with stats
    disease_stat = stats_df[stats_df["disease"]==disease].iloc[0]
    axes[idx].set_title(
        f"{disease}\n"
        f"Unique: {disease_stat['unique_symptoms']:.0f} | "
        f"Avg: {disease_stat['avg_symptoms']:.1f} | "
        f"Core: {disease_stat['frequent_itemsets']:.0f}",
        fontweight="bold", fontsize=10
    )
    axes[idx].invert_yaxis()
    axes[idx].grid(axis="x", alpha=0.3)

plt.suptitle("Symptom Profiles: Selected Diseases", 
             fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig("disease_symptom_profiles.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# Extract rules for 6 interesting diseases
interesting_rules_collection = {}

print("\n" + "="*80)
print("RULES FOR INTERESTING DISEASES")
print("="*80)

for disease in interesting_diseases:
    disease_df = df_raw[df_raw["Disease"] == disease]
    disease_transactions = convert_to_transactions(disease_df)
    
    # Run Apriori
    miner = AprioriMiner(min_support=0.9)
    miner.fit(disease_transactions)
    rules = miner.generate_rules(min_confidence=0.5, min_lift=1.0)
    
    rules_df = miner.get_rules_df()
    rules_df["disease"] = disease
    
    interesting_rules_collection[disease] = rules_df
    
    print(f"\n{disease}:")
    print(f"  Rules: {len(rules_df)}")
    if len(rules_df) > 0:
        print(f"  Top rule: {rules_df.iloc[0]['rule_str']}")
        print(f"    Confidence: {rules_df.iloc[0]['confidence']:.2%}")
        print(f"    Lift: {rules_df.iloc[0]['lift']:.2f}")

# Combine all
interesting_rules_df = pd.concat(
    interesting_rules_collection.values(), 
    ignore_index=True
)

print(f"\n\nTotal rules for interesting diseases: {len(interesting_rules_df)}")
# interesting_rules_df.to_csv("interesting_disease_rules.csv", index=False)
# Out:
# ================================================================================
# RULES FOR INTERESTING DISEASES
# ================================================================================
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 17 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 136 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 624 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1806 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 3486 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 4620 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 4236 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 2649 frequent 8-itemsets
# Generating 9-itemsets...
#   Found 1081 frequent 9-itemsets
# Generating 10-itemsets...
#   Found 260 frequent 10-itemsets
# Generating 11-itemsets...
#   Found 28 frequent 11-itemsets
# Generating 12-itemsets...
# Total frequent itemsets: 18943
#
# Generated 1398972 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Common Cold:
#   Rules: 1398972
#   Top rule:  phlegm →  redness_of_eyes
#     Confidence: 100.00%
#     Lift: 1.00
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 16 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 120 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 504 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 1302 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 2184 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 2436 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 1800 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 849 frequent 8-itemsets
# Generating 9-itemsets...
#   Found 232 frequent 9-itemsets
# Generating 10-itemsets...
#   Found 28 frequent 10-itemsets
# Generating 11-itemsets...
# Total frequent itemsets: 9471
#
# Generated 460010 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Tuberculosis:
#   Rules: 460010
#   Top rule:  malaise →  swelled_lymph_nodes
#     Confidence: 100.00%
#     Lift: 1.00
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 14 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 91 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 280 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 455 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 406 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 189 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 36 frequent 7-itemsets
# Generating 8-itemsets...
# Total frequent itemsets: 1471
#
# Generated 19170 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Dengue:
#   Rules: 19170
#   Top rule:  headache →  pain_behind_the_eyes
#     Confidence: 100.00%
#     Lift: 1.00
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 13 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 78 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 230 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 365 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 321 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 148 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 28 frequent 7-itemsets
# Generating 8-itemsets...
# Total frequent itemsets: 1183
#
# Generated 15372 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Hepatitis E:
#   Rules: 15372
#   Top rule:  abdominal_pain →  yellowing_of_eyes
#     Confidence: 100.00%
#     Lift: 1.00
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 13 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 72 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 215 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 380 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 411 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 268 frequent 6-itemsets
# Generating 7-itemsets...
#   Found 97 frequent 7-itemsets
# Generating 8-itemsets...
#   Found 15 frequent 8-itemsets
# Generating 9-itemsets...
# Total frequent itemsets: 1471
#
# Generated 29862 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Hypothyroidism:
#   Rules: 29862
#   Top rule:  abnormal_menstruation →  enlarged_thyroid
#     Confidence: 100.00%
#     Lift: 1.00
# Fitting Apriori with min_support=0.9 (count=108)
# Total transactions: 120
# Generating 1-itemsets...
#   Found 12 frequent 1-itemsets
# Generating 2-itemsets...
#   Found 66 frequent 2-itemsets
# Generating 3-itemsets...
#   Found 164 frequent 3-itemsets
# Generating 4-itemsets...
#   Found 201 frequent 4-itemsets
# Generating 5-itemsets...
#   Found 120 frequent 5-itemsets
# Generating 6-itemsets...
#   Found 28 frequent 6-itemsets
# Generating 7-itemsets...
# Total frequent itemsets: 591
#
# Generated 4730 association rules
#   Min confidence: 0.5
#   Min lift: 1.0
#
# Hepatitis B:
#   Rules: 4730
#   Top rule:  receiving_blood_transfusion →  yellowing_of_eyes
#     Confidence: 100.00%
#     Lift: 1.00
#
#
# Total rules for interesting diseases: 1928116

# %%
fig = plt.figure(figsize=(20, 12))
gs = fig.add_gridspec(3, 3, hspace=0.35, wspace=0.3)

# 1. Rules per disease
ax1 = fig.add_subplot(gs[0, 0])
rules_per_disease = interesting_rules_df.groupby("disease").size().sort_values()
bars1 = ax1.barh(range(len(rules_per_disease)), rules_per_disease.values,
                  color=plt.cm.viridis(np.linspace(0.3, 0.9, len(rules_per_disease))))
ax1.set_yticks(range(len(rules_per_disease)))
ax1.set_yticklabels(rules_per_disease.index, fontsize=10)
ax1.set_xlabel("Number of Rules")
ax1.set_title("Rules Extracted per Disease", fontweight="bold", fontsize=11)
ax1.grid(axis="x", alpha=0.3)
for i, v in enumerate(rules_per_disease.values):
    ax1.text(v + 0.5, i, str(v), va="center", fontsize=9)

# 2. Average confidence by disease
ax2 = fig.add_subplot(gs[0, 1])
avg_conf = interesting_rules_df.groupby("disease")["confidence"].mean().sort_values()
bars2 = ax2.barh(range(len(avg_conf)), avg_conf.values,
                  color=plt.cm.plasma(np.linspace(0.3, 0.9, len(avg_conf))))
ax2.set_yticks(range(len(avg_conf)))
ax2.set_yticklabels(avg_conf.index, fontsize=10)
ax2.set_xlabel("Average Confidence")
ax2.set_xlim(0, 1)
ax2.set_title("Rule Quality: Avg Confidence", fontweight="bold", fontsize=11)
ax2.grid(axis="x", alpha=0.3)
for i, v in enumerate(avg_conf.values):
    ax2.text(v + 0.02, i, f"{v:.2f}", va="center", fontsize=9)

# 3. Average lift by disease
ax3 = fig.add_subplot(gs[0, 2])
avg_lift = interesting_rules_df.groupby("disease")["lift"].mean().sort_values()
bars3 = ax3.barh(range(len(avg_lift)), avg_lift.values,
                  color=plt.cm.coolwarm(np.linspace(0.3, 0.9, len(avg_lift))))
ax3.set_yticks(range(len(avg_lift)))
ax3.set_yticklabels(avg_lift.index, fontsize=10)
ax3.set_xlabel("Average Lift")
ax3.set_title("Rule Strength: Avg Lift", fontweight="bold", fontsize=11)
ax3.grid(axis="x", alpha=0.3)
for i, v in enumerate(avg_lift.values):
    ax3.text(v + 0.05, i, f"{v:.2f}", va="center", fontsize=9)

# 4. Distribution: Confidence
ax4 = fig.add_subplot(gs[1, 0])
ax4.hist(interesting_rules_df["confidence"], bins=30, color="steelblue", 
         alpha=0.7, edgecolor="black")
ax4.axvline(interesting_rules_df["confidence"].mean(), color="red", 
            linestyle="--", linewidth=2, label=f'Mean: {interesting_rules_df["confidence"].mean():.2f}')
ax4.set_xlabel("Confidence")
ax4.set_ylabel("Number of Rules")
ax4.set_title("Distribution of Rule Confidence", fontweight="bold", fontsize=11)
ax4.legend()
ax4.grid(alpha=0.3)

# 5. Distribution: Lift
ax5 = fig.add_subplot(gs[1, 1])
ax5.hist(interesting_rules_df["lift"], bins=30, color="coral", 
         alpha=0.7, edgecolor="black")
ax5.axvline(interesting_rules_df["lift"].mean(), color="red", 
            linestyle="--", linewidth=2, label=f'Mean: {interesting_rules_df["lift"].mean():.2f}')
ax5.set_xlabel("Lift")
ax5.set_ylabel("Number of Rules")
ax5.set_title("Distribution of Rule Lift", fontweight="bold", fontsize=11)
ax5.legend()
ax5.grid(alpha=0.3)

# 6. Distribution: Support
ax6 = fig.add_subplot(gs[1, 2])
ax6.hist(interesting_rules_df["support"], bins=30, color="seagreen", 
         alpha=0.7, edgecolor="black")
ax6.axvline(interesting_rules_df["support"].mean(), color="red", 
            linestyle="--", linewidth=2, label=f'Mean: {interesting_rules_df["support"].mean():.3f}')
ax6.set_xlabel("Support")
ax6.set_ylabel("Number of Rules")
ax6.set_title("Distribution of Rule Support", fontweight="bold", fontsize=11)
ax6.legend()
ax6.grid(alpha=0.3)

# 7. Antecedent size distribution
ax7 = fig.add_subplot(gs[2, 0])
interesting_rules_df["antecedent_size"] = interesting_rules_df["antecedent"].apply(len)
ant_size_dist = interesting_rules_df["antecedent_size"].value_counts().sort_index()
ax7.bar(ant_size_dist.index, ant_size_dist.values, color="steelblue", alpha=0.7)
ax7.set_xlabel("Antecedent Size")
ax7.set_ylabel("Number of Rules")
ax7.set_title("Rule Antecedent Size Distribution", fontweight="bold", fontsize=11)
ax7.grid(axis="y", alpha=0.3)

# 8. Consequent size distribution
ax8 = fig.add_subplot(gs[2, 1])
interesting_rules_df["consequent_size"] = interesting_rules_df["consequent"].apply(len)
cons_size_dist = interesting_rules_df["consequent_size"].value_counts().sort_index()
ax8.bar(cons_size_dist.index, cons_size_dist.values, color="coral", alpha=0.7)
ax8.set_xlabel("Consequent Size")
ax8.set_ylabel("Number of Rules")
ax8.set_title("Rule Consequent Size Distribution", fontweight="bold", fontsize=11)
ax8.grid(axis="y", alpha=0.3)

# 9. Confidence vs Lift scatter
ax9 = fig.add_subplot(gs[2, 2])
scatter = ax9.scatter(interesting_rules_df["confidence"], 
                     interesting_rules_df["lift"],
                     c=interesting_rules_df["support"]*100,
                     s=50, alpha=0.6, cmap="viridis", edgecolors="black", linewidth=0.5)
ax9.set_xlabel("Confidence")
ax9.set_ylabel("Lift")
ax9.set_title("Confidence vs Lift\n(color = support %)", fontweight="bold", fontsize=11)
ax9.grid(alpha=0.3)
cbar = plt.colorbar(scatter, ax=ax9)
cbar.set_label("Support (%)", rotation=270, labelpad=15)

plt.suptitle("Association Rules Analysis Dashboard", 
             fontsize=16, fontweight="bold", y=0.995)
# plt.savefig("rules_analysis_dashboard.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Top Rules for Interesting Diseases
#
# This section extracts and displays the top association rules for each interesting disease, sorted by confidence and lift. We show the top 5 rules per disease (or all if fewer), along with key metrics.

# %%
# Extract and display top rules for each interesting disease
for disease in interesting_diseases:
    rules_df = interesting_rules_collection.get(disease)
    if rules_df is None or rules_df.empty:
        print(f"\n{disease}: No rules generated.")
        continue
    
    # Filter for high-quality rules
    filtered_rules = rules_df[(rules_df['confidence'] > 0.7) & (rules_df['lift'] > 1.2)]
    if filtered_rules.empty:
        print(f"\n{disease}: No high-quality rules (confidence > 70%, lift > 1.2).")
        continue
    
    # Sort by confidence, then lift
    top_rules = filtered_rules.sort_values(['confidence', 'lift'], ascending=[False, False]).head(5)
    
    print(f"\n{disease} - Top {len(top_rules)} Rules:")
    for idx, row in top_rules.iterrows():
        print(f"  Rule: {row['rule_str']}")
        print(f"    Support: {row['support']*100:.1f}%, Confidence: {row['confidence']*100:.1f}%, Lift: {row['lift']:.2f}")
        print()
# Out:
# Common Cold: No high-quality rules (confidence > 70%, lift > 1.2).
#
# Tuberculosis: No high-quality rules (confidence > 70%, lift > 1.2).
#
# Dengue: No high-quality rules (confidence > 70%, lift > 1.2).
#
# Hepatitis E: No high-quality rules (confidence > 70%, lift > 1.2).
#
# Hypothyroidism: No high-quality rules (confidence > 70%, lift > 1.2).
#
# Hepatitis B: No high-quality rules (confidence > 70%, lift > 1.2).

# %%
# Visualizations for top rules
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data for all diseases
all_top_rules = []
for disease in interesting_diseases:
    rules_df = interesting_rules_collection.get(disease)
    if rules_df is not None and not rules_df.empty:
        filtered = rules_df[(rules_df['confidence'] > 0.7) & (rules_df['lift'] > 1.2)]
        top = filtered.sort_values(['confidence', 'lift'], ascending=[False, False]).head(5)
        top = top.copy()
        top['disease'] = disease
        all_top_rules.append(top)

if all_top_rules:
    combined_df = pd.concat(all_top_rules, ignore_index=True)
    
    if combined_df.empty:
        print("No high-quality rules to visualize after filtering.")
    else:
        # Overall scatter plot: Confidence vs Lift
        fig, ax = plt.subplots(figsize=(10, 6))
        scatter = ax.scatter(combined_df['confidence'], combined_df['lift'], 
                             c=combined_df['disease'].astype('category').cat.codes, 
                             s=combined_df['support']*1000, alpha=0.7, cmap='tab10')
        ax.set_xlabel('Confidence')
        ax.set_ylabel('Lift')
        ax.set_title('Top Rules: Confidence vs Lift (Size = Support)')
        ax.grid(alpha=0.3)
        
        # Legend
        handles, labels = scatter.legend_elements(prop="colors")
        disease_labels = combined_df['disease'].unique()
        ax.legend(handles, disease_labels, title="Disease")
        
        # plt.savefig('top_rules_scatter.png', dpi=300, bbox_inches='tight')
        plt.show()
        
        # Per-disease bar charts for top rules
        diseases_with_rules = combined_df['disease'].unique()
        n_diseases = len(diseases_with_rules)
        fig, axes = plt.subplots(n_diseases, 2, figsize=(14, 4*n_diseases), squeeze=False)
        
        for i, disease in enumerate(diseases_with_rules):
            disease_rules = combined_df[combined_df['disease'] == disease]
            
            # Confidence bar
            axes[i, 0].barh(range(len(disease_rules)), disease_rules['confidence'], 
                            color=plt.cm.viridis(disease_rules['lift'] / disease_rules['lift'].max()))
            axes[i, 0].set_yticks(range(len(disease_rules)))
            axes[i, 0].set_yticklabels(disease_rules['rule_str'], fontsize=8)
            axes[i, 0].set_xlabel('Confidence')
            axes[i, 0].set_title(f'{disease} - Confidence')
            axes[i, 0].grid(axis='x', alpha=0.3)
            
            # Lift bar
            axes[i, 1].barh(range(len(disease_rules)), disease_rules['lift'], 
                            color=plt.cm.plasma(disease_rules['confidence']))
            axes[i, 1].set_yticks(range(len(disease_rules)))
            axes[i, 1].set_yticklabels(disease_rules['rule_str'], fontsize=8)
            axes[i, 1].set_xlabel('Lift')
            axes[i, 1].set_title(f'{disease} - Lift')
            axes[i, 1].grid(axis='x', alpha=0.3)
        
        plt.tight_layout()
        # plt.savefig('top_rules_bars.png', dpi=300, bbox_inches='tight')
        plt.show()
else:
    print("No high-quality rules to visualize.")
# Out:
# No high-quality rules to visualize after filtering.
